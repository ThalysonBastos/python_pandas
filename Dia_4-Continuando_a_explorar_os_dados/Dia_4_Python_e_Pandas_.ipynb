# %%
import pandas as pd

dados_2010_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/ThalysonBastos/python_pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %%
emprestimos_biblioteca = pd.concat([dados_2010_1, dados_2010_2, dados_2011_1, dados_2011_2, dados_2013_1, dados_2013_2, dados_2014_1, dados_2014_2, dados_2015_1, dados_2015_2, dados_2016_1, dados_2016_2,
                                    dados_2017_1, dados_2017_2, dados_2018_1, dados_2018_2, dados_2019_1, dados_2019_2, dados_2020_1], ignore_index=True)

emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2007976        2989086    2008047044                            NaN
# 2007977        2989087    2008047047                            NaN
# 2007978        2989088    2010052905                            NaN
# 2007979        2989089    2010048023                            NaN
# 2007980        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2        2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3        2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...                                ...                            ...
# 2007976  2020/05/05 19:51:06.059000000  2021/05/13 14:53:31.000000000
# 2007977  2020/05/05 19:51:06.135000000  2021/05/13 14:53:38.000000000
# 2007978  2020/05/05 19:51:06.164000000  2021/05/13 15:01:46.000000000
# 2007979  2020/06/09 11:54:02.669000000  2021/07/21 15:33:55.000000000
# 2007980  2020/06/09 11:54:02.852000000  2021/07/21 15:33:45.000000000
#
#          matricula_ou_siape             tipo_vinculo_usuario
# 0              2.008023e+09               ALUNO DE GRADUAÇÃO
# 1              2.008023e+09               ALUNO DE GRADUAÇÃO
# 2              2.008112e+09           ALUNO DE PÓS-GRADUAÇÃO
# 3              2.007211e+08               ALUNO DE GRADUAÇÃO
# 4              2.008023e+09               ALUNO DE GRADUAÇÃO
# ...                     ...                              ...
# 2007976        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2007977        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2007978        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2007979        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
# 2007980        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
#
# [2007981 rows x 7 columns]

# %%
emprestimos_biblioteca.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# 2351391        L195470        2016/01/17 16:03:38.760000000  2016/01/02 10:12:01.462000000  2016/01/27 16:37:55.000000000  2.014036e+09        ALUNO DE GRADUAÇÃO        2
#                                                                                                                                                                         ..
# 1612207        L188513        2013/10/14 17:50:25.051000000  2013/10/09 13:10:40.431000000  2013/11/04 17:43:02.000000000  2.010044e+09        ALUNO DE GRADUAÇÃO        1
# 1612208        2010034151     2013/10/24 21:13:27.383000000  2013/10/09 13:11:41.103000000  2013/11/04 19:00:18.000000000  2.013083e+09        ALUNO DE GRADUAÇÃO        1
# 1612209        L114027        2013/10/19 15:16:47.753000000  2013/10/09 13:13:13.879000000  2013/11/04 15:51:56.000000000  2.013026e+09        ALUNO DE GRADUAÇÃO        1
# 1612211        2012042689     2013/10/24 22:57:35.477000000  2013/10/09 13:20:44.388000000  2013/11/08 14:39:57.000000000  2.009050e+09        ALUNO DE GRADUAÇÃO        1
# 10322328       2014070441     2018/01/15 12:26:00.697000000  2017/12/29 18:21:09.060000000  2018/01/31 18:50:25.000000000  2.014063e+09        ALUNO DE GRADUAÇÃO        1
# Name: count, Length: 854041, dtype: int64

# %%
#Excluindo duplicatas
emprestimos_biblioteca = emprestimos_biblioteca.drop_duplicates()

# %%
emprestimos_biblioteca.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2423269        2016035106     2016/05/22 06:03:06.965000000  2016/04/24 14:47:30.049000000  2016/05/22 08:24:50.000000000  2.017400e+10        ALUNO DE PÓS-GRADUAÇÃO    1
# 2423109        2016013126     2016/05/07 20:20:25.674000000  2016/04/24 13:08:19.850000000  2016/05/17 11:48:20.000000000  2.015310e+09        ALUNO MÉDIO/TÉCNICO       1
# 2423110        2015013579     2016/05/23 11:20:49.412000000  2016/04/24 13:08:49.888000000  2016/07/07 11:01:34.000000000  2.017102e+10        ALUNO DE PÓS-GRADUAÇÃO    1
# 2423111        2015013553     2016/05/23 11:20:49.384000000  2016/04/24 13:08:49.926000000  2016/07/07 11:01:39.000000000  2.017102e+10        ALUNO DE PÓS-GRADUAÇÃO    1
#                                                                                                                                                                         ..
# 1612202        Y005622        2013/10/24 11:19:30.235000000  2013/10/09 13:07:48.984000000  2013/11/06 13:05:55.000000000  2.009057e+09        ALUNO DE GRADUAÇÃO        1
# 1612207        L188513        2013/10/14 17:50:25.051000000  2013/10/09 13:10:40.431000000  2013/11/04 17:43:02.000000000  2.010044e+09        ALUNO DE GRADUAÇÃO        1
# 1612208        2010034151     2013/10/24 21:13:27.383000000  2013/10/09 13:11:41.103000000  2013/11/04 19:00:18.000000000  2.013083e+09        ALUNO DE GRADUAÇÃO        1
# 1612209        L114027        2013/10/19 15:16:47.753000000  2013/10/09 13:13:13.879000000  2013/11/04 15:51:56.000000000  2.013026e+09        ALUNO DE GRADUAÇÃO        1
# 10322328       2014070441     2018/01/15 12:26:00.697000000  2017/12/29 18:21:09.060000000  2018/01/31 18:50:25.000000000  2.014063e+09        ALUNO DE GRADUAÇÃO        1
# Name: count, Length: 854041, dtype: int64

# %%
emprestimos_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# 3        2.007211e+08      ALUNO DE GRADUAÇÃO
# 8        2.009046e+09      ALUNO DE GRADUAÇÃO

# %%
#importando mais dados
dados_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')

dados_exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# 3                          Biblioteca Central Zila Mamede         REGULAR
# 5                          Biblioteca Central Zila Mamede        ESPECIAL
# ...                                                   ...             ...
# 568580  Biblioteca Setorial do Núcleo de Educação da I...         REGULAR
# 568581                     Biblioteca Central Zila Mamede        ESPECIAL
# 568582                     Biblioteca Central Zila Mamede        ESPECIAL
# 568583                     Biblioteca Central Zila Mamede        ESPECIAL
# 568584                     Biblioteca Central Zila Mamede        ESPECIAL
#
#         localizacao  registro_sistema
# index
# 0               694                 1
# 1               688                 1
# 2               638                 1
# 3               616                 5
# 5               657                15
# ...             ...               ...
# 568580          951            268231
# 568581          997            268233
# 568582          987            268234
# 568583          764            268235
# 568584          962            268236
#
# [546237 rows x 7 columns]

# %%
#Unindo os dataFrames
emprestimos_completo = emprestimos_biblioteca.merge(dados_exemplares)
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 1851152        2989018    2009036492                            NaN
# 1851153        2989020    2014062640                            NaN
# 1851154        2989032    2018003324                            NaN
# 1851155        2989049    2006024313                            NaN
# 1851156        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3        2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4        2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
# ...                                ...                            ...
# 1851152  2020/03/17 19:49:10.187000000  2020/12/03 08:12:20.000000000
# 1851153  2020/03/17 19:51:15.700000000  2021/01/07 11:16:28.000000000
# 1851154  2020/03/17 20:00:11.416000000  2021/08/30 13:29:44.000000000
# 1851155  2020/03/17 20:47:18.741000000                            NaN
# 1851156  2020/03/17 21:22:22.138000000  2021/07/26 15:05:20.000000000
#
#          matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 0              2.008023e+09      ALUNO DE GRADUAÇÃO        13259
# 1              2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259
# 2              2.008023e+09      ALUNO DE GRADUAÇÃO        70865
# 3              2.008050e+09      ALUNO DE GRADUAÇÃO        70865
# 4              2.007226e+08      ALUNO DE GRADUAÇÃO        70865
# ...                     ...                     ...          ...
# 1851152        2.015011e+10      ALUNO DE GRADUAÇÃO       274820
# 1851153        2.019004e+10      ALUNO DE GRADUAÇÃO      1157915
# 1851154        2.019102e+10  ALUNO DE PÓS-GRADUAÇÃO      1317173
# 1851155        2.015013e+10      ALUNO DE GRADUAÇÃO       206073
# 1851156        2.020001e+10      ALUNO DE GRADUAÇÃO      1342535
#
#                    colecao                                         biblioteca  \
# 0        Acervo Circulante                     Biblioteca Central Zila Mamede
# 1        Acervo Circulante                     Biblioteca Central Zila Mamede
# 2        Acervo Circulante                     Biblioteca Central Zila Mamede
# 3        Acervo Circulante                     Biblioteca Central Zila Mamede
# 4        Acervo Circulante                     Biblioteca Central Zila Mamede
# ...                    ...                                                ...
# 1851152  Acervo Circulante                     Biblioteca Central Zila Mamede
# 1851153  Acervo Circulante                     Biblioteca Central Zila Mamede
# 1851154  Acervo Circulante  Biblioteca Setorial da Faculdade de Ciências d...
# 1851155  Acervo Circulante                     Biblioteca Central Zila Mamede
# 1851156  Acervo Circulante                     Biblioteca Central Zila Mamede
#
#         status_material  localizacao  registro_sistema
# 0               REGULAR          630              4225
# 1               REGULAR          630              4225
# 2               REGULAR          647             25009
# 3               REGULAR          647             25009
# 4               REGULAR          647             25009
# ...                 ...          ...               ...
# 1851152         REGULAR          676            120845
# 1851153         REGULAR          228            213248
# 1851154         REGULAR          784            255835
# 1851155         REGULAR          663             82178
# 1851156         REGULAR          355            174443
#
# [1851157 rows x 13 columns]

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema
# 0              4225
# 1              4225
# 2             25009
# 3             25009
# 4             25009

# %%
#atribuindo coluna com nomeclatura da CDU

CDU_lista = []
for CDU in emprestimos_completo['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosifia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências Sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe Vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e Ciências Naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências Aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas Artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biologia. História')

emprestimos_completo['CDU_geral'] = CDU_lista

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema           CDU_geral
# 0              4225  Ciências Aplicadas
# 1              4225  Ciências Aplicadas
# 2             25009  Ciências Aplicadas
# 3             25009  Ciências Aplicadas
# 4             25009  Ciências Aplicadas

# %%
#Excluindo uma coluna no sistema "registro_sistema"
emprestimos_completo.drop(columns=['registro_sistema'], inplace=True)

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências Aplicadas
# 1  Ciências Aplicadas
# 2  Ciências Aplicadas
# 3  Ciências Aplicadas
# 4  Ciências Aplicadas

# %%
#Modificando tipo de dado da matrícula para string
emprestimos_completo['matricula_ou_siape'] = emprestimos_completo['matricula_ou_siape'].astype('string')

# %%
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências Aplicadas
# 1  Ciências Aplicadas
# 2  Ciências Aplicadas
# 3  Ciências Aplicadas
# 4  Ciências Aplicadas

# %%
#Explorando o DateTime
#Note que o "id_emprestimo" é cada empréstimo realizado que pode ter 1 ou mais exemplares.
#Portando cada linha é o empréstimo de cada exemplar.

emprestimos_completo.loc[emprestimos_completo['id_emprestimo']==1775991]
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 1358694        1775991    2010082015  2014/07/27 19:01:41.405000000
# 1358695        1775991    2010082015  2014/07/27 19:01:41.405000000
# 1358696        1775991    2010082015  2014/07/27 19:01:41.405000000
#
#                        data_emprestimo                 data_devolucao  \
# 1358694  2014/07/14 15:35:51.822000000  2014/08/13 18:37:32.000000000
# 1358695  2014/07/14 15:35:51.822000000  2014/08/13 18:37:32.000000000
# 1358696  2014/07/14 15:35:51.822000000  2014/08/13 18:37:32.000000000
#
#         matricula_ou_siape tipo_vinculo_usuario  id_exemplar  \
# 1358694       2011045050.0   ALUNO DE GRADUAÇÃO      1055921
# 1358695       2011045050.0   ALUNO DE GRADUAÇÃO      1055569
# 1358696       2011045050.0   ALUNO DE GRADUAÇÃO      1056359
#
#                    colecao                      biblioteca status_material  \
# 1358694  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 1358695  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 1358696  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
#
#          localizacao           CDU_geral
# 1358694          671  Ciências Aplicadas
# 1358695          699  Ciências Aplicadas
# 1358696          363    Ciências Sociais

# %%
emprestimos_completo['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 1775991     3
# 2772079     3
# 1987946     3
# 10114792    3
# 9690168     3
#            ..
# 2927575     1
# 10137428    1
# 9669304     1
# 9532660     1
# 2989061     1
# Name: count, Length: 1847582, dtype: int64

# %%
#Quantos emprestimos foram realizados no total

emprestimos_total = len(emprestimos_completo['id_emprestimo'].drop_duplicates())
emprestimos_total

print('O número de empréstimos total foi de: ' + str(emprestimos_total))
# Out:
# O número de empréstimos total foi de: 1847582

# %%
#Quantos exemplares foram no total

exemplares_total = len(emprestimos_completo['id_exemplar'].drop_duplicates())
exemplares_total

print('O número de exemplares total foi de: ' + str(exemplares_total))
# Out:
# O número de exemplares total foi de: 231764

# %%
#quantidade de exemplares emprestados por ano

emprestimos_data = pd.DataFrame(emprestimos_completo['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['data', 'quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_data
# Out:
#                            data  quantidade
# 0       2014-01-28 14:49:50.505           3
# 1       2018-11-22 18:28:01.619           3
# 2       2017-11-06 19:52:32.782           3
# 3       2015-06-02 17:56:18.917           3
# 4       2014-07-14 15:35:51.822           3
# ...                         ...         ...
# 1847545 2011-01-11 11:21:47.288           1
# 1847546 2014-07-31 19:06:36.559           1
# 1847547 2013-06-14 17:15:12.199           1
# 1847548 2011-01-11 10:34:57.118           1
# 1847549 2020-03-17 21:22:22.138           1
#
# [1847550 rows x 2 columns]

# %%
emprestimos_por_ano = emprestimos_data.groupby(emprestimos_data['data'].dt.year)['quantidade'].sum()
emprestimos_por_ano.index.name = 'ano'
emprestimos_por_ano
# Out:
# ano
# 2010    161394
# 2011    196390
# 2013    234749
# 2014    219189
# 2015    213582
# 2016    215900
# 2017    218462
# 2018    194080
# 2019    171801
# 2020     25610
# Name: quantidade, dtype: int64

# %%
#configurando o tema dos gráficos

sns.set_theme(context='notebook',
              style='darkgrid',
              palette='deep',
              font_scale=1.3,
              rc={"figure.figsize":(15,8)})

# %%
ax = sns.lineplot(data=emprestimos_por_ano.reset_index(), x='ano', y='quantidade')# Convert the Series to a DataFrame using reset_index()
ax.set(xlabel=None, ylabel=None)
ax.tick_params(axis='x', rotation=45)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

ax.set_title('Quantidade de empréstimos por ano' + '\n', size=20, loc='left', weight='bold')
ax.set_ylabel('Quantidade de empréstimos', size=15)

ax=ax

# %%
emprestimos_data.data
# Out:
# 0         2014-01-28 14:49:50.505
# 1         2018-11-22 18:28:01.619
# 2         2017-11-06 19:52:32.782
# 3         2015-06-02 17:56:18.917
# 4         2014-07-14 15:35:51.822
#                     ...
# 1847545   2011-01-11 11:21:47.288
# 1847546   2014-07-31 19:06:36.559
# 1847547   2013-06-14 17:15:12.199
# 1847548   2011-01-11 10:34:57.118
# 1847549   2020-03-17 21:22:22.138
# Name: data, Length: 1847550, dtype: datetime64[ns]

# %%
#emprestimos por hora
emprestimos_por_hora = emprestimos_data.groupby(emprestimos_data['data'].dt.hour)['quantidade'].sum()
emprestimos_por_hora.index.name = 'hora'
emprestimos_por_hora
# Out:
# hora
# 0         17
# 6         13
# 7      16913
# 8      91928
# 9     116285
# 10    165531
# 11    160342
# 12    132847
# 13    112486
# 14    134727
# 15    149033
# 16    188912
# 17    166415
# 18    164361
# 19     91261
# 20    113706
# 21     46101
# 22       228
# 23        51
# Name: quantidade, dtype: int64

# %%
emprestimos_por_hora = emprestimos_por_hora.sort_values(ascending=True)

emprestimos_por_hora_df = emprestimos_por_hora.reset_index()
emprestimos_por_hora_df.columns = ['horas', 'quantidade']
emprestimos_por_hora_df
# Out:
#     horas  quantidade
# 0       6          13
# 1       0          17
# 2      23          51
# 3      22         228
# 4       7       16913
# 5      21       46101
# 6      19       91261
# 7       8       91928
# 8      13      112486
# 9      20      113706
# 10      9      116285
# 11     12      132847
# 12     14      134727
# 13     15      149033
# 14     11      160342
# 15     18      164361
# 16     10      165531
# 17     17      166415
# 18     16      188912

# %%
ax = sns.barplot(data=emprestimos_por_hora_df, y='quantidade', x='horas',
                 palette='Greens', hue='quantidade', dodge=False)
plt.legend([],[], frameon=False)

ax.set(xlabel='Horário', ylabel=None)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

ax.set_title('Quantidade de empréstimos por hora' + '\n', size=20, loc='left', weight='bold')

ax=ax

# %%
#modificando tipo de dados da data de empréstimos do DataFrame
emprestimos_completo['data_emprestimo'] = pd.to_datetime(emprestimos_completo['data_emprestimo'])

# %%
#verificando os valores únicos das variáveis
emprestimos_completo.tipo_vinculo_usuario.unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'DOCENTE EXTERNO', 'SERVIDOR TÉCNICO-ADMINISTRATIVO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
#verificando coleção
emprestimos_completo.colecao.unique()
# Out:
# array(['Acervo Circulante', 'Folhetos', 'Teses', 'Dissertações',
#        'Monografias', 'Publicações de Autores do RN',
#        'Publicações da UFRN', 'Multimeios', 'Coleção Mossoroense',
#        'Eventos', 'Trabalho Acadêmico', 'Obras de Referência',
#        'Obras Raras', 'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
#verificando biblioteca
emprestimos_completo.biblioteca.unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
#        'Biblioteca Setorial Árvore do Conhecimento - Instituto do Cérebro - ICe',
#        'Biblioteca Setorial Moacyr de Góes - CE',
#        'Biblioteca Setorial Prof. Leopoldo Nelson - \xadCentro de Biociências - CB',
#        'Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN - Caicó',
#        'Biblioteca Setorial Pe. Jaime Diniz - Escola de Música - EMUFRN',
#        'Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - \xadCERES\xad - Caicó',
#        'Biblioteca Setorial Profª. Maria José Mamede Galvão - FELCS - Currais Novos',
#        'Biblioteca Setorial do Núcleo de Educação da Infância - NEI',
#        'Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz',
#        'Biblioteca Setorial do Núcleo de Ensino Superior do Agreste - NESA - Nova Cruz'],
#       dtype=object)

# %%
#verificando as CDU Geral
emprestimos_completo.CDU_geral.unique()
# Out:
# array(['Ciências Aplicadas', 'Linguagem', 'Ciências Sociais',
#        'Geografia. Biologia. História', 'Matemática e Ciências Naturais',
#        'Religião', 'Generalidades', 'Filosifia e psicologia',
#        'Belas Artes'], dtype=object)

# %%
#Esta função irá gerar uma tabela de frequencia com percentuais de acordo com a variável passada

#variável = variável categórica escolhida de dentro do conjunto de dados emprestimos completo

def tabela_frequencia(variavel):
  dataframe = pd.DataFrame(emprestimos_completo[variavel].value_counts())
  dataframe.columns = ['quantidade']
  dataframe['percentual'] = round((dataframe.quantidade / dataframe.quantidade.sum())*100,1)

  return dataframe

# %%
tabela_frequencia('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1433463        77.4
# ALUNO DE PÓS-GRADUAÇÃO               273758        14.8
# DOCENTE                               63777         3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       28897         1.6
# ALUNO MÉDIO/TÉCNICO                   25550         1.4
# DOCENTE EXTERNO                       23363         1.3
# USUÁRIO EXTERNO                        2344         0.1
# OUTROS                                    5         0.0

# %%
tabela_frequencia('colecao')
# Out:
#                                        quantidade  percentual
# colecao
# Acervo Circulante                         1834313        99.1
# Multimeios                                   6750         0.4
# Monografias                                  3517         0.2
# Dissertações                                 2052         0.1
# Obras de Referência                          1849         0.1
# Publicações de Autores do RN                  770         0.0
# Publicações da UFRN                           679         0.0
# Teses                                         601         0.0
# Folhetos                                      232         0.0
# Necessidades Educacionais Específicas         116         0.0
# Trabalho Acadêmico                             96         0.0
# Eventos                                        91         0.0
# Coleção Mossoroense                            38         0.0
# Literatura de Cordel                           24         0.0
# Coleção Zila Mamede                            24         0.0
# Obras Raras                                     5         0.0

# %%
tabela_frequencia('biblioteca')
# Out:
#                                                     quantidade  percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1266239        68.4
# Biblioteca Setorial do Centro Ciências da Saúde...      103400         5.6
# Biblioteca Setorial da Faculdade de Ciências da...       67186         3.6
# Biblioteca Setorial Prof. Alberto Moreira Campo...       60393         3.3
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       56794         3.1
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       40546         2.2
# Biblioteca Setorial do Centro de Ciências Human...       37628         2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32089         1.7
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       25348         1.4
# Biblioteca Setorial Profª. Maria José Mamede Ga...       25055         1.4
# Biblioteca Setorial Prof. Francisco Gurgel De A...       24555         1.3
# Biblioteca Setorial do Núcleo de Educação da In...       23418         1.3
# Biblioteca Setorial Prof. Ronaldo Xavier de Arr...       20234         1.1
# Biblioteca Setorial Pe. Jaime Diniz - Escola de...       18785         1.0
# Biblioteca Setorial do Departamento de Artes - ...       16099         0.9
# Biblioteca Setorial Prof. Leopoldo Nelson - ­Ce...       12798         0.7
# Biblioteca Setorial do Centro Ciências Sociais ...        9941         0.5
# Biblioteca Setorial Prof. Dr. Marcelo Bezerra d...        4603         0.2
# Biblioteca Setorial Prof. Horácio Nicolas Solim...        3572         0.2
# Biblioteca Setorial Moacyr de Góes - CE                    950         0.1
# Biblioteca Setorial Árvore do Conhecimento - In...         907         0.0
# Biblioteca Setorial do Núcleo de Ensino Superio...         617         0.0
